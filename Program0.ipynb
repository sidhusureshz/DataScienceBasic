# %%
#arithematic operations
a=int(input("enter the first number"))
b=int(input("enter the second number"))
print("ARITHEMATIC OPERATION :")
print("Addition ",a+b)
print("Subtraction ",a-b)
print("Multiplication ",a*b)
if b==0:
    print("not divisible by zero")
else:
    print("Division ",a/b)
print("Exponation ",a**b)
# Out:
# enter the first number 12
# enter the second number 6
# ARITHEMATIC OPERATION :
# Addition  18
# Subtraction  6
# Multiplication  72
# Division  2.0
# Exponation  2985984

# %%
#strings
a=input("enter a string")
b=input("enter another string")
c=a+" "+b
print("STRING OPERATIONS ")
print("First string is ",a)
print("concatenation gives",c)
print("Repitation",a*3)
print("indexing",a[0])
print("silicing",a[1:3])
print("Length of a",len(a))
print("replace a to b",b.replace("a","b"))
print("String formatting: hello {}".format(a))
print("capitalize",a.capitalize())
print("Upper case :",a.upper())
print("Justify :",a.rjust(20))
print("To center :",a.center(20))
text=" python "
print("Text stripping :",text.strip())
# Out:
# enter a string helloo
# enter another string worldd
# STRING OPERATIONS
# First string is  helloo
# concatenation gives helloo worldd
# Repitation helloohelloohelloo
# indexing h
# silicing el
# Length of a 6
# replace a to b worldd
# String formatting: hello helloo
# capitalize Helloo
# Upper case : HELLOO
# Justify :               helloo
# To center :        helloo
# Text stripping : python

# %%
#lists
list=input("enter the list of numbers").split(" ")
print(list)
print("print element at index",list[0])
print("last element using negative indexing",list[-1])
list[0]='foo'
print(list)
list.append('bar')
print("add element to end of list",list)
last=list.pop()
print(last)
print("remove and return last element",list)
print(list[1:3])
# Out:
# enter the list of numbers 3 1 2
# ['3', '1', '2']
# print element at index 3
# last element using negative indexing 2
# ['foo', '1', '2']
# add element to end of list ['foo', '1', '2', 'bar']
# bar
# remove and return last element ['foo', '1', '2']
# ['1', '2']

# %%
#range
nums=[0,1,2,3,4,5]
for i in range(5):
    print(i)
#slicing    
print("after slicing",nums[2:4])
# Out:
# 0
# 1
# 2
# 3
# 4
# after slicing [2, 3]

# %%
# For loop
print("For loop:")
for i in range(1, 4):
    print(i)
    
#While loop
print("While loop:")
count = 1
while count <= 3:
    print(count)
    count += 1
# Nested loop
print("Nested loop:")
for i in range(1, 3):
    for j in range(1, 3):
        print(i, j)
# Out:
# For loop:
# 1
# 2
# 3
# While loop:
# 1
# 2
# 3
# Nested loop:
# 1 1
# 1 2
# 2 1
# 2 2

# %%
#dictionaries
dict1 = {"name1": "sidhu", "age": 21}
dict2 = {"name2": "ihsan", "age": 33}

merged = dict1 | dict2
print(merged)
# Out:
# {'name1': 'sidhu', 'age': 33, 'name2': 'ihsan'}

# %%
#write a script to get the largest number from list#merge 2 dictories
dict1={"name1":32}
dict2={"name2":23}
print("merged dict:",dict1|dict2)
list=[2,3,4,7,1]
print("largest number:",max(list))
# Out:
# merged dict: {'name1': 32, 'name2': 23}
# largest number: 7

# %%
#write a program to remove duplictes from list
num=[2,3,2,1]
print("remove duplicate value list:",list(set(num)))
# Out:
# remove duplicate value list: [1, 2, 3]
